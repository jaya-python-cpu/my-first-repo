# %% [markdown]
# Hardware referes to the physical parts of a computer that we can see and touch, such as a keyboard or monitor. Software refers to programs or instructions that run on a computer and tell it what to do, such as an operating system. For example, keyboard is hardware and windows is software.

# %%
print("Hello World")
# Out:
# Hello World
